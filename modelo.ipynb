# %%
import pulp
import numpy as np
import math

np.random.seed(999)

# %% [markdown]
# ### Dados

# %%
num_pessoas = 20
num_equipes = 4
conhecimento_min = 1
conhecimento_max = 10
t_min = 4
t_max = 6
prob_alta_afinidade = 0.3
prob_seniors = 0.15  
penalidade = 15.0 # penalização por não ter sênior

# %%
# Conhecimento de cada pessoa em cada framework
conhecimento = np.random.randint(conhecimento_min, conhecimento_max+1, size=(num_pessoas, num_equipes))

# Pares com afinidade muito alta que não podem estar na mesma equipe
alta_afinidade = np.random.choice([0, 1], size=(num_pessoas, num_pessoas), p=[1 - prob_alta_afinidade, prob_alta_afinidade])
np.fill_diagonal(alta_afinidade, 0)
for i in range(num_pessoas):
    for j in range(i+1, num_pessoas):
        alta_afinidade[j, i] = alta_afinidade[i, j]

# senior[i] = 1 se i for senior
num_seniors = math.floor(prob_seniors * num_pessoas)
senior = np.zeros(num_pessoas, dtype=int)
seniors_indices = np.random.choice(num_pessoas, size=num_seniors, replace=False)
senior[seniors_indices] = 1

# %%
model = pulp.LpProblem("hackathon", pulp.LpMinimize)

# %% [markdown]
# ### Variáveis

# %%
# Xij = Pessoa i na equipe j? 
x = pulp.LpVariable.dicts("x", ((i,j) for i in range(num_pessoas) for j in range(num_equipes)), cat='Binary')

# Sj = Equipe j possui algum senior ?
s = pulp.LpVariable.dicts("s", (j for j in range(num_equipes)), cat='Binary')

# Pj = Pontuação da equipe j
P = pulp.LpVariable.dicts("P", (j for j in range(num_equipes)), lowBound=0, cat='Continuous')

# Pontuações das equipes com maior e menor pontuação
P_max = pulp.LpVariable("P_max", lowBound=0, cat='Continuous')
P_min = pulp.LpVariable("P_min", lowBound=0, cat='Continuous')

# %% [markdown]
# ### Restrições

# %%
# Cada pessoa deve estar em exatamente uma equipe
for i in range(num_pessoas):
    model += pulp.lpSum(x[i,j] for j in range(num_equipes)) == 1

# Tamanho da equipe entre t_min e t_max
for j in range(num_equipes):
    model += pulp.lpSum(x[i,j] for i in range(num_pessoas)) >= t_min
    model += pulp.lpSum(x[i,j] for i in range(num_pessoas)) <= t_max

# Proibir pares com afinidade alta de estarem na mesma equipe
for j in range(num_equipes):
    for i in range(num_pessoas):
        for k in range(i+1, num_pessoas):
            if alta_afinidade[i, k] == 1:
                model += x[i, j] + x[k, j] <= 1

# s_j = 1 se equipe j tiver um sênior
for j in range(num_equipes):
    model += s[j] == pulp.lpSum(senior[i] * x[i,j] for i in range(num_pessoas))
    model += pulp.lpSum(senior[i] * x[i,j] for i in range(num_pessoas)) <= 1 # max 1 senior por equipe

# Calcular pontuação Pj
for j in range(num_equipes):
    conhecimento_total = pulp.lpSum(conhecimento[i, j] * x[i, j] for i in range(num_pessoas))
    model += P[j] == conhecimento_total - penalidade * (1 - s[j])

# Objetivo é minimizar P_max - P_min
for j in range(num_equipes):
    model += P[j] <= P_max
    model += P[j] >= P_min

# %%
model += P_max - P_min
solver = pulp.PULP_CBC_CMD(msg=True)
model.solve(solver)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/andre/python/pesquisa_operacional/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/80781dd9958e4a76a11bf8c806b4a278-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/80781dd9958e4a76a11bf8c806b4a278-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 281 COLUMNS
# At line 1280 RHS
# At line 1557 BOUNDS
# At line 1642 ENDATA
# Problem MODEL has 276 rows, 90 columns and 828 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 93 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23 strengthened rows, 0 substitutions
# Cgl0004I processed model has 190 rows, 86 columns (84 integer (84 of which binary)) and 774 elements
# Cbc0038I Initial state - 53 integers unsatisfied sum - 14.5463
# Cbc0038I Pass   1: suminf.    5.00000 (10) obj. 13 iterations 55
# Cbc0038I Pass   2: suminf.    5.00000 (10) obj. 13 iterations 3
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 10 iterations 25
# Cbc0038I Solution found of 10
# Cbc0038I Relaxing continuous gives 10
# Cbc0038I Before mini branch and bound, 29 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 190 rows 86 columns, reduced to 109 rows 45 columns
# Cbc0038I Mini branch and bound improved solution from 10 to 10 (0.05 seconds)
# Cbc0038I Round again with cutoff of 8.99999
# Cbc0038I Pass   4: suminf.    5.47059 (14) obj. 8.99999 iterations 13
# Cbc0038I Pass   5: suminf.    0.15385 (6) obj. 8.99999 iterations 37
# Cbc0038I Pass   6: suminf.    0.15385 (6) obj. 8.99999 iterations 2
# Cbc0038I Pass   7: suminf.    2.92308 (6) obj. 8.99999 iterations 29
# Cbc0038I Pass   8: suminf.    3.51352 (10) obj. 8.99999 iterations 27
# Cbc0038I Pass   9: suminf.    2.59854 (8) obj. 8.99999 iterations 48
# Cbc0038I Pass  10: suminf.    2.64706 (6) obj. 8.99999 iterations 41
# Cbc0038I Pass  11: suminf.    0.80000 (6) obj. 8.99999 iterations 28
# Cbc0038I Pass  12: suminf.    1.22628 (32) obj. 8.99999 iterations 35
# Cbc0038I Pass  13: suminf.    0.80000 (6) obj. 8.99999 iterations 19
# Cbc0038I Pass  14: suminf.   12.03226 (55) obj. 8.99999 iterations 71
# Cbc0038I Pass  15: suminf.    7.82416 (52) obj. 8.99999 iterations 34
# Cbc0038I Pass  16: suminf.    2.00000 (6) obj. 8.99999 iterations 8
# Cbc0038I Pass  17: suminf.    2.00000 (6) obj. 8.99999 iterations 18
# Cbc0038I Pass  18: suminf.    1.04804 (6) obj. 8.99999 iterations 40
# Cbc0038I Pass  19: suminf.    2.20000 (6) obj. 8.99999 iterations 35
# Cbc0038I Pass  20: suminf.    2.16919 (9) obj. 8.99999 iterations 14
# Cbc0038I Pass  21: suminf.    0.35294 (6) obj. 8.99999 iterations 29
# Cbc0038I Pass  22: suminf.    0.15385 (6) obj. 8.99999 iterations 15
# Cbc0038I Pass  23: suminf.    2.92308 (6) obj. 8.99999 iterations 25
# Cbc0038I Pass  24: suminf.    3.41177 (11) obj. 8.99999 iterations 46
# Cbc0038I Pass  25: suminf.    2.59854 (8) obj. 8.99999 iterations 67
# Cbc0038I Pass  26: suminf.    2.64706 (6) obj. 8.99999 iterations 46
# Cbc0038I Pass  27: suminf.    0.80000 (6) obj. 8.99999 iterations 32
# Cbc0038I Pass  28: suminf.    1.33605 (51) obj. 8.99999 iterations 47
# Cbc0038I Pass  29: suminf.    0.80000 (6) obj. 8.99999 iterations 46
# Cbc0038I Pass  30: suminf.    1.08108 (10) obj. 8.99999 iterations 39
# Cbc0038I Pass  31: suminf.    3.55556 (8) obj. 8.99999 iterations 32
# Cbc0038I Pass  32: suminf.    2.66667 (8) obj. 8.99999 iterations 48
# Cbc0038I Pass  33: suminf.    0.00001 (0) obj. 8.99999 iterations 56
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 190 rows 86 columns, reduced to 189 rows 85 columns - 23 fixed gives 0, 0 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of 10 - took 0.06 seconds
# Cbc0012I Integer solution of 10 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0038I Full problem 190 rows 86 columns, reduced to 109 rows 45 columns
# Cbc0031I 8 added rows had average density of 65.25
# Cbc0013I At root node, 8 cuts changed objective from -3.5527137e-15 to -7.1054274e-15 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2 column cuts (2 active)  in 0.096 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1774 row cuts average 85.6 elements, 0 column cuts (0 active)  in 0.086 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.038 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 12 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.080 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 129 row cuts average 73.8 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 10 best solution, best possible 3.5527137e-15 (0.96 seconds)
# Cbc0012I Integer solution of 7 found by DiveCoefficient after 5063 iterations and 4 nodes (1.02 seconds)
# Cbc0012I Integer solution of 5 found by DiveCoefficient after 5702 iterations and 18 nodes (1.18 seconds)
# Cbc0004I Integer solution of 3 found after 6018 iterations and 29 nodes (1.33 seconds)
# Cbc0038I Full problem 190 rows 86 columns, reduced to 105 rows 44 columns
# Cbc0038I Full problem 190 rows 86 columns, reduced to 116 rows 49 columns
# Cbc0038I Full problem 190 rows 86 columns, reduced to 118 rows 49 columns
# Cbc0038I Full problem 190 rows 86 columns, reduced to 79 rows 36 columns
# Cbc0004I Integer solution of 2 found after 25319 iterations and 430 nodes (4.44 seconds)
# Cbc0001I Search completed - best objective 2, took 33681 iterations and 702 nodes (5.60 seconds)
# Cbc0032I Strong branching done 7830 times (138689 iterations), fathomed 151 nodes and fixed 75 variables
# Cbc0041I Maximum depth 17, 209 variables fixed on reduced cost (complete fathoming 19 times, 108 nodes taking 2333 iterations)
# Cuts at root node changed objective from -3.55271e-15 to 3.55271e-15
# Probing was tried 100 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.096 seconds)
# Gomory was tried 100 times and created 1774 cuts of which 0 were active after adding rounds of cuts (0.086 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.038 seconds)
# Clique was tried 100 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.080 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
# TwoMirCuts was tried 100 times and created 129 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.00000000
# Enumerated nodes:               702
# Total iterations:               33681
# Time (CPU seconds):             5.16
# Time (Wallclock seconds):       5.61
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       5.16   (Wallclock seconds):       5.62
# 1

# %%
print(f"Status: {pulp.LpStatus[model.status]}")
print(f"Diferença entre scores máximo e mínimo: {pulp.value(P_max) - pulp.value(P_min):.2f}\n")

pontuacoes = []
for j in range(num_equipes):
    equipe = [i for i in range(num_pessoas) if pulp.value(x[i, j]) > 0.5]
    pontuacao = pulp.value(P[j])
    pontuacoes.append(pontuacao)
    tem_senior = pulp.value(s[j]) > 0.5
    conhecimento_total = 0
    
    print(f"\nEquipe {j + 1}:")
    print(f"  Membros: {equipe}")
    print(f"  Detalhes dos membros:")
    
    for i in equipe:
        eh_senior = " (Sênior)" if senior[i] else ""
        c = conhecimento[i][j]
        conhecimento_total += c
        print(f"    - Pessoa {i}: Conhecimento = {c} {eh_senior}")

    # print(f"  Afinidades entre membros (deve ser 0):")
    # for i in range(len(equipe)):
    #     for k in range(i+1, len(equipe)):
    #         a = alta_afinidade[equipe[i], equipe[k]]
    #         print(f"    - ({equipe[i]}, {equipe[k]}): {a}")

    penalidade_total = penalidade if not tem_senior else 0
    pontuacao_calculada = conhecimento_total - penalidade_total

    print(f"  Tem sênior? {'Sim' if tem_senior else 'Não'}")
    print(f"  Soma dos conhecimentos: {conhecimento_total}")
    print(f"  Penalidade por falta de sênior: {penalidade_total}")
    # print(f"  Pontuação calculada (conhecimentos - penalidade): {pontuacao_calculada:.2f}")
    print(f"  Pontuação (modelo): {pontuacao:.2f}")

print(f"\nMaior score entre as equipes: {max(pontuacoes):.2f}")
print(f"Menor score entre as equipes: {min(pontuacoes):.2f}")

# print(f"\nÍndices dos seniors: {seniors_indices.tolist()}")
# Out:
# Status: Optimal
# Diferença entre scores máximo e mínimo: 2.00
#
#
# Equipe 1:
#   Membros: [4, 5, 11, 17]
#   Detalhes dos membros:
#     - Pessoa 4: Conhecimento = 5
#     - Pessoa 5: Conhecimento = 7  (Sênior)
#     - Pessoa 11: Conhecimento = 7
#     - Pessoa 17: Conhecimento = 7
#   Tem sênior? Sim
#   Soma dos conhecimentos: 26
#   Penalidade por falta de sênior: 0
#   Pontuação (modelo): 26.00
#
# Equipe 2:
#   Membros: [8, 9, 10, 13, 15, 16]
#   Detalhes dos membros:
#     - Pessoa 8: Conhecimento = 8
#     - Pessoa 9: Conhecimento = 2
#     - Pessoa 10: Conhecimento = 2  (Sênior)
#     - Pessoa 13: Conhecimento = 7
#     - Pessoa 15: Conhecimento = 7
#     - Pessoa 16: Conhecimento = 1
#   Tem sênior? Sim
#   Soma dos conhecimentos: 27
#   Penalidade por falta de sênior: 0
#   Pontuação (modelo): 27.00
#
# Equipe 3:
#   Membros: [1, 14, 18, 19]
#   Detalhes dos membros:
#     - Pessoa 1: Conhecimento = 4
#     - Pessoa 14: Conhecimento = 10
#     - Pessoa 18: Conhecimento = 8
#     - Pessoa 19: Conhecimento = 6  (Sênior)
#   Tem sênior? Sim
#   Soma dos conhecimentos: 28
#   Penalidade por falta de sênior: 0
#   Pontuação (modelo): 28.00
#
# Equipe 4:
#   Membros: [0, 2, 3, 6, 7, 12]
#   Detalhes dos membros:
#     - Pessoa 0: Conhecimento = 9
#     - Pessoa 2: Conhecimento = 1
#     - Pessoa 3: Conhecimento = 8
#     - Pessoa 6: Conhecimento = 10
#     - Pessoa 7: Conhecimento = 8
#     - Pessoa 12: Conhecimento = 5
#   Tem sênior? Não
#   Soma dos conhecimentos: 41
#   Penalidade por falta de sênior: 15.0
#   Pontuação (modelo): 26.00
#
# Maior score entre as equipes: 28.00
# Menor score entre as equipes: 26.00
